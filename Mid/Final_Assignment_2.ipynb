# %%
# STEP 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pillow pyheif > /dev/null

# %%
import os
import pyheif
from PIL import Image

folder = "/content/drive/MyDrive/facial_dataset/Tanziul"

for filename in os.listdir(folder):
    if filename.lower().endswith(".heic"):
        heic_path = os.path.join(folder, filename)
        jpg_path = os.path.join(folder, filename.rsplit('.', 1)[0] + '.jpg')
        try:
            heif_file = pyheif.read(heic_path)
            image = Image.frombytes(
                heif_file.mode,
                heif_file.size,
                heif_file.data,
                "raw",
                heif_file.mode,
                heif_file.stride,
            )
            image.save(jpg_path, "JPEG")
            os.remove(heic_path)  # optional: delete original .heic file
            print(f"✅ Converted: {filename} → {os.path.basename(jpg_path)}")
        except Exception as e:
            print(f"❌ Failed to convert {filename}: {e}")
# Out:
# ✅ Converted: IMG_6118.HEIC → IMG_6118.jpg
# ✅ Converted: IMG_6116.HEIC → IMG_6116.jpg
# ✅ Converted: IMG_6106.HEIC → IMG_6106.jpg
# ✅ Converted: IMG_6105.HEIC → IMG_6105.jpg
# ✅ Converted: IMG_6117.HEIC → IMG_6117.jpg
# ✅ Converted: IMG_6122.HEIC → IMG_6122.jpg
# ✅ Converted: IMG_6123.HEIC → IMG_6123.jpg
# ✅ Converted: IMG_6103.HEIC → IMG_6103.jpg
# ✅ Converted: IMG_6108.HEIC → IMG_6108.jpg
# ✅ Converted: IMG_6121.HEIC → IMG_6121.jpg
# ✅ Converted: IMG_6112.HEIC → IMG_6112.jpg
# ✅ Converted: IMG_6098.HEIC → IMG_6098.jpg
# ✅ Converted: IMG_6115.HEIC → IMG_6115.jpg
# ✅ Converted: IMG_6104.HEIC → IMG_6104.jpg
# ✅ Converted: IMG_6132.HEIC → IMG_6132.jpg
# ✅ Converted: IMG_6124.HEIC → IMG_6124.jpg
# ✅ Converted: IMG_6114.HEIC → IMG_6114.jpg
# ✅ Converted: IMG_6119.HEIC → IMG_6119.jpg
# ✅ Converted: IMG_6137.HEIC → IMG_6137.jpg
# ✅ Converted: IMG_6128.HEIC → IMG_6128.jpg
# ✅ Converted: IMG_6126.HEIC → IMG_6126.jpg
# ✅ Converted: IMG_6134.HEIC → IMG_6134.jpg
# ✅ Converted: IMG_6129.HEIC → IMG_6129.jpg
# ✅ Converted: IMG_6113.HEIC → IMG_6113.jpg
# ✅ Converted: IMG_6139.HEIC → IMG_6139.jpg
# ✅ Converted: IMG_6127.HEIC → IMG_6127.jpg
# ✅ Converted: IMG_6135.HEIC → IMG_6135.jpg
# ✅ Converted: IMG_6111.HEIC → IMG_6111.jpg
# ✅ Converted: IMG_6141.HEIC → IMG_6141.jpg
# ✅ Converted: IMG_6099.HEIC → IMG_6099.jpg
# ✅ Converted: IMG_6109.HEIC → IMG_6109.jpg
# ✅ Converted: IMG_6096.HEIC → IMG_6096.jpg
# ✅ Converted: IMG_6140.HEIC → IMG_6140.jpg
# ✅ Converted: IMG_6133.HEIC → IMG_6133.jpg
# ✅ Converted: IMG_6088.HEIC → IMG_6088.jpg
# ✅ Converted: IMG_6136.HEIC → IMG_6136.jpg
# ✅ Converted: IMG_6131.HEIC → IMG_6131.jpg
# ✅ Converted: IMG_6120.HEIC → IMG_6120.jpg
# ✅ Converted: IMG_6107.HEIC → IMG_6107.jpg
# ✅ Converted: IMG_6130.HEIC → IMG_6130.jpg
# ✅ Converted: IMG_6142.HEIC → IMG_6142.jpg
# ✅ Converted: IMG_6125.HEIC → IMG_6125.jpg
# ✅ Converted: IMG_6138.HEIC → IMG_6138.jpg
# ✅ Converted: IMG_6110.HEIC → IMG_6110.jpg
# ✅ Converted: IMG_6094.HEIC → IMG_6094.jpg
# ✅ Converted: IMG_6101.HEIC → IMG_6101.jpg
# ✅ Converted: IMG_6045.HEIC → IMG_6045.jpg
# ✅ Converted: IMG_6078.HEIC → IMG_6078.jpg
# ✅ Converted: IMG_6069.HEIC → IMG_6069.jpg
# ✅ Converted: IMG_6089.HEIC → IMG_6089.jpg
# ✅ Converted: IMG_6067.HEIC → IMG_6067.jpg
# ✅ Converted: IMG_6076.HEIC → IMG_6076.jpg
# ✅ Converted: IMG_6070.HEIC → IMG_6070.jpg
# ✅ Converted: IMG_6087.HEIC → IMG_6087.jpg
# ✅ Converted: IMG_6081.HEIC → IMG_6081.jpg
# ✅ Converted: IMG_6090.HEIC → IMG_6090.jpg
# ✅ Converted: IMG_6072.HEIC → IMG_6072.jpg
# ✅ Converted: IMG_6074.HEIC → IMG_6074.jpg
# ✅ Converted: IMG_6032.HEIC → IMG_6032.jpg
# ✅ Converted: IMG_6085.HEIC → IMG_6085.jpg
# ✅ Converted: IMG_6064.HEIC → IMG_6064.jpg
# ✅ Converted: IMG_6079.HEIC → IMG_6079.jpg
# ✅ Converted: IMG_6068.HEIC → IMG_6068.jpg
# ✅ Converted: IMG_6082.HEIC → IMG_6082.jpg
# ✅ Converted: IMG_6057.HEIC → IMG_6057.jpg
# ✅ Converted: IMG_6065.HEIC → IMG_6065.jpg
# ✅ Converted: IMG_6095.HEIC → IMG_6095.jpg
# ✅ Converted: IMG_6054.HEIC → IMG_6054.jpg
# ✅ Converted: IMG_6044.HEIC → IMG_6044.jpg
# ✅ Converted: IMG_6077.HEIC → IMG_6077.jpg
# ✅ Converted: IMG_6060.HEIC → IMG_6060.jpg
# ✅ Converted: IMG_6092.HEIC → IMG_6092.jpg
# ✅ Converted: IMG_6055.HEIC → IMG_6055.jpg
# ✅ Converted: IMG_6084.HEIC → IMG_6084.jpg
# ✅ Converted: IMG_6058.HEIC → IMG_6058.jpg
# ✅ Converted: IMG_6086.HEIC → IMG_6086.jpg
# ✅ Converted: IMG_6050.HEIC → IMG_6050.jpg
# ✅ Converted: IMG_6056.HEIC → IMG_6056.jpg
# ✅ Converted: IMG_6035.HEIC → IMG_6035.jpg
# ✅ Converted: IMG_6080.HEIC → IMG_6080.jpg
# ✅ Converted: IMG_6073.HEIC → IMG_6073.jpg
# ✅ Converted: IMG_6083.HEIC → IMG_6083.jpg
# ✅ Converted: IMG_6097.HEIC → IMG_6097.jpg
# ✅ Converted: IMG_6071.HEIC → IMG_6071.jpg
# ✅ Converted: IMG_6075.HEIC → IMG_6075.jpg
# ✅ Converted: IMG_6093.HEIC → IMG_6093.jpg
# ✅ Converted: IMG_6034.HEIC → IMG_6034.jpg
# ✅ Converted: IMG_6091.HEIC → IMG_6091.jpg
# ✅ Converted: IMG_6066.HEIC → IMG_6066.jpg
# ✅ Converted: IMG_6059.HEIC → IMG_6059.jpg
# ✅ Converted: IMG_5356.HEIC → IMG_5356.jpg
# ✅ Converted: IMG_6004.HEIC → IMG_6004.jpg
# ✅ Converted: IMG_6038.HEIC → IMG_6038.jpg
# ✅ Converted: IMG_6033.HEIC → IMG_6033.jpg
# ✅ Converted: IMG_6061.HEIC → IMG_6061.jpg
# ✅ Converted: IMG_5353.HEIC → IMG_5353.jpg
# ✅ Converted: IMG_5335.HEIC → IMG_5335.jpg
# ✅ Converted: IMG_5341.HEIC → IMG_5341.jpg
# ✅ Converted: IMG_6046.HEIC → IMG_6046.jpg
# ✅ Converted: IMG_6043.HEIC → IMG_6043.jpg
# ✅ Converted: IMG_5286.HEIC → IMG_5286.jpg
# ✅ Converted: IMG_5364.HEIC → IMG_5364.jpg
# ✅ Converted: IMG_6037.HEIC → IMG_6037.jpg
# ✅ Converted: IMG_6063.HEIC → IMG_6063.jpg
# ✅ Converted: IMG_6062.HEIC → IMG_6062.jpg
# ✅ Converted: IMG_6042.HEIC → IMG_6042.jpg
# ✅ Converted: IMG_5340.HEIC → IMG_5340.jpg
# ✅ Converted: IMG_5334.HEIC → IMG_5334.jpg
# ✅ Converted: IMG_5357.HEIC → IMG_5357.jpg
# ✅ Converted: IMG_6040.HEIC → IMG_6040.jpg
# ✅ Converted: IMG_6047.HEIC → IMG_6047.jpg
# ✅ Converted: IMG_6039.HEIC → IMG_6039.jpg
# ✅ Converted: IMG_6048.HEIC → IMG_6048.jpg
# ✅ Converted: IMG_5342.HEIC → IMG_5342.jpg
# ✅ Converted: IMG_5362.HEIC → IMG_5362.jpg
# ✅ Converted: IMG_6053.HEIC → IMG_6053.jpg
# ✅ Converted: IMG_5360.HEIC → IMG_5360.jpg
# ✅ Converted: IMG_6041.HEIC → IMG_6041.jpg
# ✅ Converted: IMG_5366.HEIC → IMG_5366.jpg
# ✅ Converted: IMG_5361.HEIC → IMG_5361.jpg
# ✅ Converted: IMG_6036.HEIC → IMG_6036.jpg
# ✅ Converted: IMG_6051.HEIC → IMG_6051.jpg
# ✅ Converted: IMG_5979.HEIC → IMG_5979.jpg
# ✅ Converted: IMG_6049.HEIC → IMG_6049.jpg
# ✅ Converted: IMG_5355.HEIC → IMG_5355.jpg
# ✅ Converted: IMG_6052.HEIC → IMG_6052.jpg
# ✅ Converted: IMG_5354.HEIC → IMG_5354.jpg
# ✅ Converted: IMG_6007.HEIC → IMG_6007.jpg
# ✅ Converted: IMG_5984.HEIC → IMG_5984.jpg
# ✅ Converted: IMG_5344.HEIC → IMG_5344.jpg
# ✅ Converted: IMG_5963.HEIC → IMG_5963.jpg
# ✅ Converted: IMG_5962.HEIC → IMG_5962.jpg
# ✅ Converted: IMG_6008.HEIC → IMG_6008.jpg
# ✅ Converted: IMG_5986.HEIC → IMG_5986.jpg
# ✅ Converted: IMG_6026.HEIC → IMG_6026.jpg
# ✅ Converted: IMG_6025.HEIC → IMG_6025.jpg
# ✅ Converted: IMG_5991.HEIC → IMG_5991.jpg
# ✅ Converted: IMG_5988.HEIC → IMG_5988.jpg
# ✅ Converted: IMG_5968.HEIC → IMG_5968.jpg
# ✅ Converted: IMG_6024.HEIC → IMG_6024.jpg
# ✅ Converted: IMG_5964.HEIC → IMG_5964.jpg
# ✅ Converted: IMG_5967.HEIC → IMG_5967.jpg
# ✅ Converted: IMG_5993.HEIC → IMG_5993.jpg
# ✅ Converted: IMG_5969.HEIC → IMG_5969.jpg
# ✅ Converted: IMG_5970.HEIC → IMG_5970.jpg
# ✅ Converted: IMG_5959.HEIC → IMG_5959.jpg
# ✅ Converted: IMG_5972.HEIC → IMG_5972.jpg
# ✅ Converted: IMG_5966.HEIC → IMG_5966.jpg
# ✅ Converted: IMG_5989.HEIC → IMG_5989.jpg
# ✅ Converted: IMG_5994.HEIC → IMG_5994.jpg
# ✅ Converted: IMG_5997.HEIC → IMG_5997.jpg
# ✅ Converted: IMG_5995.HEIC → IMG_5995.jpg
# ✅ Converted: IMG_5365.HEIC → IMG_5365.jpg
# ✅ Converted: IMG_6018.HEIC → IMG_6018.jpg
# ✅ Converted: IMG_6027.HEIC → IMG_6027.jpg
# ✅ Converted: IMG_6006.HEIC → IMG_6006.jpg
# ✅ Converted: IMG_5981.HEIC → IMG_5981.jpg
# ✅ Converted: IMG_5965.HEIC → IMG_5965.jpg
# ✅ Converted: IMG_5980.HEIC → IMG_5980.jpg
# ✅ Converted: IMG_5987.HEIC → IMG_5987.jpg
# ✅ Converted: IMG_5978.HEIC → IMG_5978.jpg
# ✅ Converted: IMG_5957.HEIC → IMG_5957.jpg
# ✅ Converted: IMG_5960.HEIC → IMG_5960.jpg
# ✅ Converted: IMG_5358.HEIC → IMG_5358.jpg
# ✅ Converted: IMG_6005.HEIC → IMG_6005.jpg
# ✅ Converted: IMG_5961.HEIC → IMG_5961.jpg
# ✅ Converted: IMG_5998.HEIC → IMG_5998.jpg
# ✅ Converted: IMG_6021.HEIC → IMG_6021.jpg
# ✅ Converted: IMG_5338.HEIC → IMG_5338.jpg
# ✅ Converted: IMG_5990.HEIC → IMG_5990.jpg
# ✅ Converted: IMG_6016.HEIC → IMG_6016.jpg
# ✅ Converted: IMG_5985.HEIC → IMG_5985.jpg
# ✅ Converted: IMG_6019.HEIC → IMG_6019.jpg
# ✅ Converted: IMG_6100.HEIC → IMG_6100.jpg
# ✅ Converted: IMG_6011.HEIC → IMG_6011.jpg
# ✅ Converted: IMG_5996.HEIC → IMG_5996.jpg
# ✅ Converted: IMG_6010.HEIC → IMG_6010.jpg
# ✅ Converted: IMG_5347.HEIC → IMG_5347.jpg
# ✅ Converted: IMG_5958.HEIC → IMG_5958.jpg
# ✅ Converted: IMG_5976.HEIC → IMG_5976.jpg
# ✅ Converted: IMG_5977.HEIC → IMG_5977.jpg
# ✅ Converted: IMG_6009.HEIC → IMG_6009.jpg
# ✅ Converted: IMG_5351.HEIC → IMG_5351.jpg
# ✅ Converted: IMG_5352.HEIC → IMG_5352.jpg
# ✅ Converted: IMG_5346.HEIC → IMG_5346.jpg
# ✅ Converted: IMG_5971.HEIC → IMG_5971.jpg
# ✅ Converted: IMG_5973.HEIC → IMG_5973.jpg
# ✅ Converted: IMG_6013.HEIC → IMG_6013.jpg
# ✅ Converted: IMG_6017.HEIC → IMG_6017.jpg
# ✅ Converted: IMG_5983.HEIC → IMG_5983.jpg
# ✅ Converted: IMG_5349.HEIC → IMG_5349.jpg
# ✅ Converted: IMG_6012.HEIC → IMG_6012.jpg
# ✅ Converted: IMG_6022.HEIC → IMG_6022.jpg
# ✅ Converted: IMG_6020.HEIC → IMG_6020.jpg
# ✅ Converted: IMG_5975.HEIC → IMG_5975.jpg
# ✅ Converted: IMG_6023.HEIC → IMG_6023.jpg
# ✅ Converted: IMG_5350.HEIC → IMG_5350.jpg
# ✅ Converted: IMG_5348.HEIC → IMG_5348.jpg
# ✅ Converted: IMG_6015.HEIC → IMG_6015.jpg
# ✅ Converted: IMG_5974.HEIC → IMG_5974.jpg
# ✅ Converted: IMG_5982.HEIC → IMG_5982.jpg
# ✅ Converted: IMG_5345.HEIC → IMG_5345.jpg
# ✅ Converted: IMG_6014.HEIC → IMG_6014.jpg

# %%
# Face Recognition Attendance System using MobileNetV2 in Google Colab

# STEP 1: Import Libraries
import os
import cv2
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras import Input

# %%
path = '/content/drive/MyDrive/facial_dataset'
folder_name = []
folder_paths  =[]
for root, folder, files in os.walk(path):
    folder_name.extend(folder)
    full_paths = [path+'/'+ f for f in folder]
    folder_paths.extend(full_paths)
print(folder_name)
print(folder_paths)
# Out:
# ['Sameer', 'Prithoy', 'Tanziul', 'Niloy']
# ['/content/drive/MyDrive/facial_dataset/Sameer', '/content/drive/MyDrive/facial_dataset/Prithoy', '/content/drive/MyDrive/facial_dataset/Tanziul', '/content/drive/MyDrive/facial_dataset/Niloy']

# %%
folder_path=[]
for i in folder_paths:
    folder_path.append(i+'/')
folder_path
# Out:
# ['/content/drive/MyDrive/facial_dataset/Sameer/',
#  '/content/drive/MyDrive/facial_dataset/Prithoy/',
#  '/content/drive/MyDrive/facial_dataset/Tanziul/',
#  '/content/drive/MyDrive/facial_dataset/Niloy/']

# %%
persons = [[] for _ in folder_path]
for i in range(len(folder_path)):
    for _, _, file_name in os.walk(folder_path[i]):
        persons[i].extend(file_name)

# %%
person_1=[]
person_2=[]
person_3=[]
person_4=[]
for i in range(len(persons)):
    for j in range(len(persons[i])):
        if(i == 0):
            person = persons[i][j]
            label = folder_name[i]
            classification=0
            person_1.append([person, label,classification])
        elif(i == 1):
            person = persons[i][j]
            label = folder_name[i]
            classification=1
            person_2.append([person, label, classification])
        elif(i == 2):
            person = persons[i][j]
            label = folder_name[i]
            classification=2
            person_3.append([person, label, classification])
        elif(i == 3):
            person = persons[i][j]
            label = folder_name[i]
            classification=3
            person_4.append([person, label, classification])

# %%
full_data = []
for i in range(4):
    if i == 0:
        for i in range(len(person_1)):
            full_data.append(person_1[i])
    elif i == 1:
        for i in range(len(person_2)):
            full_data.append(person_2[i])
    elif i == 2:
        for i in range(len(person_3)):
            full_data.append(person_3[i])
    elif i == 3:
        for i in range(len(person_4)):
            full_data.append(person_4[i])
print(len(person_1), len(person_2), len(person_3), len(person_4))
random.shuffle(full_data)
len(full_data)
# Out:
# 232 136 203 174
# 745

# %%
plt.figure(figsize=(20,10))
c=0
for i in range(5):
    plt.subplot(1,5,c+1)
    if(full_data[i][2] == 0):
        img_path = os.path.join(folder_path[0], full_data[i][0])
    elif(full_data[i][2]==1):
        img_path = os.path.join(folder_path[1], full_data[i][0])
    elif(full_data[i][2]==2):
        img_path = os.path.join(folder_path[2], full_data[i][0])
    elif(full_data[i][2]==3):
        img_path = os.path.join(folder_path[3], full_data[i][0])

    image = cv2.imread(img_path)
    image = cv2.resize(image, (227,227))
    image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    print(image.shape)
    plt.imshow(image)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(full_data[i][1])
    plt.ylabel(full_data[i][2])
    c+=1
# Out:
# (227, 227, 3)
# (227, 227, 3)
# (227, 227, 3)
# (227, 227, 3)
# (227, 227, 3)

# %%
len(full_data)
# Out:
# 745

# %%
test_size = round((len(full_data)*.15))

test_data = random.sample(full_data, test_size)

train_data = [data for data in full_data if data not in test_data]

print(f"Test Data ({test_size} samples): {test_data}")
print(f"Train Data ({len(train_data)} samples): {train_data}")
# Out:
# Test Data (112 samples): [['IMG_20250624_125753.jpg', 'Sameer', 0], ['IMG_20250624_125930.jpg', 'Sameer', 0], ['IMG_6084.jpg', 'Tanziul', 2], ['IMG_20250615_231956_97.jpg', 'Niloy', 3], ['IMG_20250615_231956_45.jpg', 'Niloy', 3], ['IMG_20250624_125717_1.jpg', 'Sameer', 0], ['IMG_20250624_170329_TIMEBURST59.jpg', 'Niloy', 3], ['IMG_6034.jpg', 'Tanziul', 2], ['IMG_20250615_233742_32.jpg', 'Prithoy', 1], ['IMG_6044.jpg', 'Tanziul', 2], ['IMG_20250615_231956_65.jpg', 'Niloy', 3], ['IMG_20250615_231956_135.jpg', 'Niloy', 3], ['IMG_20250624_170329_TIMEBURST56.jpg', 'Niloy', 3], ['IMG_20250615_233742_157.jpg', 'Prithoy', 1], ['IMG_20250615_231956_113.jpg', 'Niloy', 3], ['IMG_20250624_130011.jpg', 'Sameer', 0], ['IMG_20250615_231956_133.jpg', 'Niloy', 3], ['IMG_20250624_125756.jpg', 'Sameer', 0], ['IMG_20250624_170329_TIMEBURST75.jpg', 'Niloy', 3], ['IMG_6126.jpg', 'Tanziul', 2], ['IMG_6120.jpg', 'Tanziul', 2], ['IMG_20250615_231956_58.jpg', 'Niloy', 3], ['IMG_20250624_170329_57.jpg', 'Niloy', 3], ['IMG_20250624_170329_TIMEBURST49.jpg', 'Niloy', 3], ['IMG_20250624_130027.jpg', 'Sameer', 0], ['IMG_20250615_233742_85.jpg', 'Prithoy', 1], ['IMG_20250624_125718.jpg', 'Sameer', 0], ['IMG_5366.jpg', 'Tanziul', 2], ['IMG_20250615_233742_78.jpg', 'Prithoy', 1], ['IMG_20250615_233742_103.jpg', 'Prithoy', 1], ['IMG_20250624_125712_1.jpg', 'Sameer', 0], ['IMG_20250615_233742_63.jpg', 'Prithoy', 1], ['IMG_20250615_231956_98.jpg', 'Niloy', 3], ['IMG_20250615_233742_107.jpg', 'Prithoy', 1], ['IMG_6018.jpg', 'Tanziul', 2], ['IMG_20250624_125945.jpg', 'Sameer', 0], ['IMG_20250624_130013.jpg', 'Sameer', 0], ['IMG_20250615_231956_17.jpg', 'Niloy', 3], ['IMG_20250615_231956_12.jpg', 'Niloy', 3], ['IMG_20250615_233742_26.jpg', 'Prithoy', 1], ['IMG_20250624_125711_2.jpg', 'Sameer', 0], ['IMG_5995.jpg', 'Tanziul', 2], ['IMG_20250615_233742_27.jpg', 'Prithoy', 1], ['IMG_20250624_125731.jpg', 'Sameer', 0], ['IMG_20250615_233742_59.jpg', 'Prithoy', 1], ['IMG_20250624_125943_1.jpg', 'Sameer', 0], ['IMG_20250615_231956_121.jpg', 'Niloy', 3], ['IMG_20250624_130021.jpg', 'Sameer', 0], ['IMG_5974.jpg', 'Tanziul', 2], ['IMG_6067.jpg', 'Tanziul', 2], ['IMG_6109.jpg', 'Tanziul', 2], ['IMG_20250624_130023.jpg', 'Sameer', 0], ['IMG_6055.jpg', 'Tanziul', 2], ['IMG_6086.jpg', 'Tanziul', 2], ['IMG_20250624_125801_1.jpg', 'Sameer', 0], ['IMG_6093.jpg', 'Tanziul', 2], ['IMG_20250615_233742_83.jpg', 'Prithoy', 1], ['IMG_6023.jpg', 'Tanziul', 2], ['IMG_5997.jpg', 'Tanziul', 2], ['IMG_20250624_125939_1.jpg', 'Sameer', 0], ['IMG_6101.jpg', 'Tanziul', 2], ['IMG_5961.jpg', 'Tanziul', 2], ['IMG_20250624_125758.jpg', 'Sameer', 0], ['IMG_20250624_125806.jpg', 'Sameer', 0], ['IMG_5340.jpg', 'Tanziul', 2], ['IMG_20250624_125713_1.jpg', 'Sameer', 0], ['IMG_20250615_233742_44.jpg', 'Prithoy', 1], ['IMG_20250615_233742_35.jpg', 'Prithoy', 1], ['IMG_20250615_233742_41.jpg', 'Prithoy', 1], ['IMG_20250615_231956_83.jpg', 'Niloy', 3], ['IMG_6129.jpg', 'Tanziul', 2], ['IMG_20250615_233742_142.jpg', 'Prithoy', 1], ['IMG_20250615_231956_20.jpg', 'Niloy', 3], ['IMG_20250624_170329_TIMEBURST48.jpg', 'Niloy', 3], ['IMG_20250624_125809.jpg', 'Sameer', 0], ['IMG_20250624_125713.jpg', 'Sameer', 0], ['IMG_5354.jpg', 'Tanziul', 2], ['IMG_5959.jpg', 'Tanziul', 2], ['IMG_20250615_233742_136.jpg', 'Prithoy', 1], ['IMG_20250615_231956_148.jpg', 'Niloy', 3], ['IMG_6111.jpg', 'Tanziul', 2], ['IMG_20250624_130015.jpg', 'Sameer', 0], ['IMG_6050.jpg', 'Tanziul', 2], ['IMG_20250615_231956_50.jpg', 'Niloy', 3], ['IMG_20250615_231956_144.jpg', 'Niloy', 3], ['IMG_20250624_130023_2.jpg', 'Sameer', 0], ['IMG_20250615_231956_91.jpg', 'Niloy', 3], ['IMG_20250615_233742_8.jpg', 'Prithoy', 1], ['IMG_20250615_231956_109.jpg', 'Niloy', 3], ['IMG_6005.jpg', 'Tanziul', 2], ['IMG_20250624_130001.jpg', 'Sameer', 0], ['IMG_20250615_231956_101.jpg', 'Niloy', 3], ['IMG_20250615_233742_46.jpg', 'Prithoy', 1], ['IMG_5361.jpg', 'Tanziul', 2], ['IMG_20250615_231956_89.jpg', 'Niloy', 3], ['IMG_20250624_130011_1.jpg', 'Sameer', 0], ['I ...
# Train Data (633 samples): [['IMG_20250615_231956_26.jpg', 'Niloy', 3], ['IMG_20250615_233742_52.jpg', 'Prithoy', 1], ['IMG_20250624_170329_TIMEBURST77.jpg', 'Niloy', 3], ['IMG_6037.jpg', 'Tanziul', 2], ['IMG_20250624_125743_2.jpg', 'Sameer', 0], ['IMG_6098.jpg', 'Tanziul', 2], ['IMG_20250624_130022.jpg', 'Sameer', 0], ['IMG_5970.jpg', 'Tanziul', 2], ['IMG_5358.jpg', 'Tanziul', 2], ['IMG_20250624_125724.jpg', 'Sameer', 0], ['IMG_20250624_130017.jpg', 'Sameer', 0], ['IMG_6025.jpg', 'Tanziul', 2], ['IMG_20250624_125747_1.jpg', 'Sameer', 0], ['IMG_20250624_125752.jpg', 'Sameer', 0], ['IMG_20250624_125945_1.jpg', 'Sameer', 0], ['IMG_6107.jpg', 'Tanziul', 2], ['IMG_20250615_231956_86.jpg', 'Niloy', 3], ['IMG_20250624_125716_1.jpg', 'Sameer', 0], ['IMG_20250624_125725.jpg', 'Sameer', 0], ['IMG_5963.jpg', 'Tanziul', 2], ['IMG_5341.jpg', 'Tanziul', 2], ['IMG_20250615_231956_107.jpg', 'Niloy', 3], ['IMG_20250624_130003.jpg', 'Sameer', 0], ['IMG_20250615_233742_113.jpg', 'Prithoy', 1], ['IMG_20250624_125809_1.jpg', 'Sameer', 0], ['IMG_20250624_125801.jpg', 'Sameer', 0], ['IMG_5957.jpg', 'Tanziul', 2], ['IMG_5968.jpg', 'Tanziul', 2], ['IMG_20250624_125756_1.jpg', 'Sameer', 0], ['IMG_5983.jpg', 'Tanziul', 2], ['IMG_5334.jpg', 'Tanziul', 2], ['IMG_5960.jpg', 'Tanziul', 2], ['IMG_20250624_125718_1.jpg', 'Sameer', 0], ['IMG_6032.jpg', 'Tanziul', 2], ['IMG_20250615_233742_125.jpg', 'Prithoy', 1], ['IMG_20250624_125929.jpg', 'Sameer', 0], ['IMG_20250624_125723.jpg', 'Sameer', 0], ['IMG_20250615_231956_139.jpg', 'Niloy', 3], ['IMG_20250615_233742_66.jpg', 'Prithoy', 1], ['IMG_20250624_125937.jpg', 'Sameer', 0], ['IMG_6081.jpg', 'Tanziul', 2], ['IMG_20250624_125952.jpg', 'Sameer', 0], ['IMG_20250624_125946_1.jpg', 'Sameer', 0], ['IMG_5967.jpg', 'Tanziul', 2], ['IMG_20250615_231956_28.jpg', 'Niloy', 3], ['IMG_20250624_170329_TIMEBURST78.jpg', 'Niloy', 3], ['IMG_6108.jpg', 'Tanziul', 2], ['IMG_20250615_233742_70.jpg', 'Prithoy', 1], ['IMG_20250624_125746_2.jpg', 'Sameer', 0], ['IMG_20250624_125718_3.jpg', 'Sameer', 0], ['IMG_20250624_130013_1.jpg', 'Sameer', 0], ['IMG_20250615_233742_16.jpg', 'Prithoy', 1], ['IMG_20250624_125959_1.jpg', 'Sameer', 0], ['IMG_5976.jpg', 'Tanziul', 2], ['IMG_20250615_233742_123.jpg', 'Prithoy', 1], ['IMG_20250615_231956_132.jpg', 'Niloy', 3], ['IMG_20250615_231956_66.jpg', 'Niloy', 3], ['IMG_20250615_233742_114.jpg', 'Prithoy', 1], ['IMG_20250624_125759_1.jpg', 'Sameer', 0], ['IMG_20250615_233742_120.jpg', 'Prithoy', 1], ['IMG_6004.jpg', 'Tanziul', 2], ['IMG_20250615_231956_2.jpg', 'Niloy', 3], ['IMG_6137.jpg', 'Tanziul', 2], ['IMG_5348.jpg', 'Tanziul', 2], ['IMG_20250615_231956_60.jpg', 'Niloy', 3], ['IMG_5986.jpg', 'Tanziul', 2], ['IMG_20250624_130024_1.jpg', 'Sameer', 0], ['IMG_20250624_130019_1.jpg', 'Sameer', 0], ['IMG_20250624_170329_TIMEBURST68.jpg', 'Niloy', 3], ['IMG_20250624_125942.jpg', 'Sameer', 0], ['IMG_20250615_233742_43.jpg', 'Prithoy', 1], ['IMG_5346.jpg', 'Tanziul', 2], ['IMG_20250624_130008_1.jpg', 'Sameer', 0], ['IMG_5987.jpg', 'Tanziul', 2], ['IMG_20250624_130019.jpg', 'Sameer', 0], ['IMG_20250624_170329_TIMEBURST65.jpg', 'Niloy', 3], ['IMG_20250615_233742_24.jpg', 'Prithoy', 1], ['IMG_6117.jpg', 'Tanziul', 2], ['IMG_20250624_125934.jpg', 'Sameer', 0], ['IMG_20250615_233742_39.jpg', 'Prithoy', 1], ['IMG_20250615_233742_3.jpg', 'Prithoy', 1], ['IMG_20250615_233742_105.jpg', 'Prithoy', 1], ['IMG_20250615_231956_77.jpg', 'Niloy', 3], ['IMG_20250624_170329_53.jpg', 'Niloy', 3], ['IMG_20250624_125714_2.jpg', 'Sameer', 0], ['IMG_6016.jpg', 'Tanziul', 2], ['IMG_20250615_233742_36.jpg', 'Prithoy', 1], ['IMG_20250615_233742_97.jpg', 'Prithoy', 1], ['IMG_6058.jpg', 'Tanziul', 2], ['IMG_20250624_125949.jpg', 'Sameer', 0], ['IMG_20250624_125750_1.jpg', 'Sameer', 0], ['IMG_20250615_233742_67.jpg', 'Prithoy', 1], ['IMG_20250624_170329_78.jpg', 'Niloy', 3], ['IMG_6106.jpg', 'Tanziul', 2], ['IMG_6076.jpg', 'Tanziul', 2], ['IMG_20250624_130008.jpg', 'Sameer', 0], ['IMG_6073.jpg', 'Tanziul', 2], ['IMG_20250624_12574 ...

# %%
image_shape=(227,227)

# %%
X_train = []
Y_train=[]
for data in train_data:
    label = data[2]
    Y_train.append(label)
    if label == 0:
        img_path = os.path.join(folder_path[0], data[0])
    elif label == 1:
        img_path = os.path.join(folder_path[1], data[0])
    elif label == 2:
        img_path = os.path.join(folder_path[2], data[0])
    elif label == 3:
        img_path = os.path.join(folder_path[3], data[0])
    else:
        continue
    image = cv2.imread(img_path)
    image = cv2.resize(image,image_shape)
    if image is not None:
        X_train.append(image)

X_train = np.array(X_train)
Y_train=np.array(Y_train)
Y_train = np.reshape(Y_train, (-1, 1))
print(f"Shape of X is : {X_train.shape}")
print(f"Shape of Y is : {Y_train.shape}")
# Out:
# Shape of X is : (633, 227, 227, 3)
# Shape of Y is : (633, 1)

# %%
X_test =[]
Y_test=[]
for data in test_data:
    label = data[2]
    if label == 0:
        img_path = os.path.join(folder_path[0],data[0])
    elif label == 1:
        img_path = os.path.join(folder_path[1],data[0])
    elif label == 2:
        img_path = os.path.join(folder_path[2],data[0])
    elif label == 3:
        img_path = os.path.join(folder_path[3],data[0])
    image = cv2.imread(img_path)
    image = cv2.resize(image, image_shape)
    X_test.append(image)
    Y_test.append(label)

X_test = np.array(X_test)
Y_test = np.array(Y_test)
Y_test = np.reshape(Y_test, (-1,1))
print(f"Shape of X is : {X_test.shape}")
print(f"Shape of Y is : {Y_test.shape}")
# Out:
# Shape of X is : (112, 227, 227, 3)
# Shape of Y is : (112, 1)

# %%
print(f"Shape of Train data : {X_train.shape} and label : {Y_train.shape}")
print(f"Shape of Test data : {X_test.shape} and label : {Y_test.shape}")
# Out:
# Shape of Train data : (633, 227, 227, 3) and label : (633, 1)
# Shape of Test data : (112, 227, 227, 3) and label : (112, 1)

# %%
i = 0
plt.figure(figsize=(20,10))
for img in range(30):
    plt.subplot(5, 6, i+1)
    image = cv2.cvtColor(X_test[img],cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.xlabel(Y_test[img])
    plt.xticks([])
    plt.yticks([])
    i +=1
plt.show()

# %%
# Normalize and mean images
train_mean = np.mean(X_train, axis=0)
test_mean = np.mean(X_test, axis=0)
X_train_norm = X_train - train_mean
X_test_norm = X_test - test_mean

# Define MobileNetV2-based model
input_shape = X_train.shape[1:]
base_model = MobileNetV2(weights='imagenet', include_top=False, input_tensor=Input(shape=input_shape))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /tmp/ipython-input-25-50104883.py:9: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False, input_tensor=Input(shape=input_shape))
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 227, 227,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 114, 114,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bn_Conv1            │ (None, 114, 114,  │        128 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1_relu (ReLU)   │ (None, 114, 114,  │          0 │ bn_Conv1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 114, 114,  │        288 │ Conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 114, 114,  │        128 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 114, 114,  │          0 │ expanded_conv_de… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 114, 114,  │        512 │ expanded_conv_de… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 114, 114,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand      │ (None, 114, 114,  │      1,536 │ expanded_conv_pr… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_BN   │ (None, 114, 114,  │        384 │ block_1_expand[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_expand_relu │ (None, 114, 114,  │          0 │ block_1_expand_B… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_pad         │ (None, 115, 115,  │          0 │ block_1_expand_r… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise   │ (None, 57, 57,    │        864 │ block_1_pad[0][0] │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 57, 57,    │        384 │ block_1_depthwis… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_depthwise_… │ (None, 57, 57,    │          0 │ block_1_depthwis… │
# │ (ReLU)              │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project     │ (None, 57, 57,    │      2,304 │ block_1_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_1_project_BN  │ (None, 57, 57,    │         96 │ block_1_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand      │ (None, 57, 57,    │      3,456 │ block_1_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_BN   │ (None, 57, 57,    │        576 │ block_2_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_expand_relu │ (None, 57, 57,    │          0 │ block_2_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise   │ (None, 57, 57,    │      1,296 │ block_2_expand_r… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 57, 57,    │        576 │ block_2_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_depthwise_… │ (None, 57, 57,    │          0 │ block_2_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project     │ (None, 57, 57,    │      3,456 │ block_2_depthwis… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_project_BN  │ (None, 57, 57,    │         96 │ block_2_project[… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_2_add (Add)   │ (None, 57, 57,    │          0 │ block_1_project_… │
# │                     │ 24)               │            │ block_2_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand      │ (None, 57, 57,    │      3,456 │ block_2_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_BN   │ (None, 57, 57,    │        576 │ block_3_expand[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_expand_relu │ (None, 57, 57,    │          0 │ block_3_expand_B… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_pad         │ (None, 59, 59,    │          0 │ block_3_expand_r… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise   │ (None, 29, 29,    │      1,296 │ block_3_pad[0][0] │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 29, 29,    │        576 │ block_3_depthwis… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_depthwise_… │ (None, 29, 29,    │          0 │ block_3_depthwis… │
# │ (ReLU)              │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project     │ (None, 29, 29,    │      4,608 │ block_3_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_3_project_BN  │ (None, 29, 29,    │        128 │ block_3_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand      │ (None, 29, 29,    │      6,144 │ block_3_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_BN   │ (None, 29, 29,    │        768 │ block_4_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_expand_relu │ (None, 29, 29,    │          0 │ block_4_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise   │ (None, 29, 29,    │      1,728 │ block_4_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 29, 29,    │        768 │ block_4_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_depthwise_… │ (None, 29, 29,    │          0 │ block_4_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project     │ (None, 29, 29,    │      6,144 │ block_4_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_project_BN  │ (None, 29, 29,    │        128 │ block_4_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_4_add (Add)   │ (None, 29, 29,    │          0 │ block_3_project_… │
# │                     │ 32)               │            │ block_4_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand      │ (None, 29, 29,    │      6,144 │ block_4_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_BN   │ (None, 29, 29,    │        768 │ block_5_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_expand_relu │ (None, 29, 29,    │          0 │ block_5_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise   │ (None, 29, 29,    │      1,728 │ block_5_expand_r… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 29, 29,    │        768 │ block_5_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_depthwise_… │ (None, 29, 29,    │          0 │ block_5_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project     │ (None, 29, 29,    │      6,144 │ block_5_depthwis… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_project_BN  │ (None, 29, 29,    │        128 │ block_5_project[… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_5_add (Add)   │ (None, 29, 29,    │          0 │ block_4_add[0][0… │
# │                     │ 32)               │            │ block_5_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand      │ (None, 29, 29,    │      6,144 │ block_5_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_BN   │ (None, 29, 29,    │        768 │ block_6_expand[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_expand_relu │ (None, 29, 29,    │          0 │ block_6_expand_B… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_pad         │ (None, 31, 31,    │          0 │ block_6_expand_r… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise   │ (None, 15, 15,    │      1,728 │ block_6_pad[0][0] │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 15, 15,    │        768 │ block_6_depthwis… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_depthwise_… │ (None, 15, 15,    │          0 │ block_6_depthwis… │
# │ (ReLU)              │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project     │ (None, 15, 15,    │     12,288 │ block_6_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_6_project_BN  │ (None, 15, 15,    │        256 │ block_6_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand      │ (None, 15, 15,    │     24,576 │ block_6_project_… │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_BN   │ (None, 15, 15,    │      1,536 │ block_7_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_expand_relu │ (None, 15, 15,    │          0 │ block_7_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise   │ (None, 15, 15,    │      3,456 │ block_7_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 15, 15,    │      1,536 │ block_7_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_depthwise_… │ (None, 15, 15,    │          0 │ block_7_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project     │ (None, 15, 15,    │     24,576 │ block_7_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_project_BN  │ (None, 15, 15,    │        256 │ block_7_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_7_add (Add)   │ (None, 15, 15,    │          0 │ block_6_project_… │
# │                     │ 64)               │            │ block_7_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand      │ (None, 15, 15,    │     24,576 │ block_7_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_BN   │ (None, 15, 15,    │      1,536 │ block_8_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_expand_relu │ (None, 15, 15,    │          0 │ block_8_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise   │ (None, 15, 15,    │      3,456 │ block_8_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 15, 15,    │      1,536 │ block_8_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_depthwise_… │ (None, 15, 15,    │          0 │ block_8_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project     │ (None, 15, 15,    │     24,576 │ block_8_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_project_BN  │ (None, 15, 15,    │        256 │ block_8_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_8_add (Add)   │ (None, 15, 15,    │          0 │ block_7_add[0][0… │
# │                     │ 64)               │            │ block_8_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand      │ (None, 15, 15,    │     24,576 │ block_8_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_BN   │ (None, 15, 15,    │      1,536 │ block_9_expand[0… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_expand_relu │ (None, 15, 15,    │          0 │ block_9_expand_B… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise   │ (None, 15, 15,    │      3,456 │ block_9_expand_r… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 15, 15,    │      1,536 │ block_9_depthwis… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_depthwise_… │ (None, 15, 15,    │          0 │ block_9_depthwis… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project     │ (None, 15, 15,    │     24,576 │ block_9_depthwis… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_project_BN  │ (None, 15, 15,    │        256 │ block_9_project[… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_9_add (Add)   │ (None, 15, 15,    │          0 │ block_8_add[0][0… │
# │                     │ 64)               │            │ block_9_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand     │ (None, 15, 15,    │     24,576 │ block_9_add[0][0] │
# │ (Conv2D)            │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_BN  │ (None, 15, 15,    │      1,536 │ block_10_expand[… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_expand_re… │ (None, 15, 15,    │          0 │ block_10_expand_… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise  │ (None, 15, 15,    │      3,456 │ block_10_expand_… │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 15, 15,    │      1,536 │ block_10_depthwi… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_depthwise… │ (None, 15, 15,    │          0 │ block_10_depthwi… │
# │ (ReLU)              │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project    │ (None, 15, 15,    │     36,864 │ block_10_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_10_project_BN │ (None, 15, 15,    │        384 │ block_10_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand     │ (None, 15, 15,    │     55,296 │ block_10_project… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_BN  │ (None, 15, 15,    │      2,304 │ block_11_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_expand_re… │ (None, 15, 15,    │          0 │ block_11_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise  │ (None, 15, 15,    │      5,184 │ block_11_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 15, 15,    │      2,304 │ block_11_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_depthwise… │ (None, 15, 15,    │          0 │ block_11_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project    │ (None, 15, 15,    │     55,296 │ block_11_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_project_BN │ (None, 15, 15,    │        384 │ block_11_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_11_add (Add)  │ (None, 15, 15,    │          0 │ block_10_project… │
# │                     │ 96)               │            │ block_11_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand     │ (None, 15, 15,    │     55,296 │ block_11_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_BN  │ (None, 15, 15,    │      2,304 │ block_12_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_expand_re… │ (None, 15, 15,    │          0 │ block_12_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise  │ (None, 15, 15,    │      5,184 │ block_12_expand_… │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 15, 15,    │      2,304 │ block_12_depthwi… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_depthwise… │ (None, 15, 15,    │          0 │ block_12_depthwi… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project    │ (None, 15, 15,    │     55,296 │ block_12_depthwi… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_project_BN │ (None, 15, 15,    │        384 │ block_12_project… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_12_add (Add)  │ (None, 15, 15,    │          0 │ block_11_add[0][… │
# │                     │ 96)               │            │ block_12_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand     │ (None, 15, 15,    │     55,296 │ block_12_add[0][… │
# │ (Conv2D)            │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_BN  │ (None, 15, 15,    │      2,304 │ block_13_expand[… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_expand_re… │ (None, 15, 15,    │          0 │ block_13_expand_… │
# │ (ReLU)              │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_pad        │ (None, 17, 17,    │          0 │ block_13_expand_… │
# │ (ZeroPadding2D)     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise  │ (None, 8, 8, 576) │      5,184 │ block_13_pad[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 8, 8, 576) │      2,304 │ block_13_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_depthwise… │ (None, 8, 8, 576) │          0 │ block_13_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project    │ (None, 8, 8, 160) │     92,160 │ block_13_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_13_project_BN │ (None, 8, 8, 160) │        640 │ block_13_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand     │ (None, 8, 8, 960) │    153,600 │ block_13_project… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_BN  │ (None, 8, 8, 960) │      3,840 │ block_14_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_expand_re… │ (None, 8, 8, 960) │          0 │ block_14_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise  │ (None, 8, 8, 960) │      8,640 │ block_14_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 8, 8, 960) │      3,840 │ block_14_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_depthwise… │ (None, 8, 8, 960) │          0 │ block_14_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project    │ (None, 8, 8, 160) │    153,600 │ block_14_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_project_BN │ (None, 8, 8, 160) │        640 │ block_14_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_14_add (Add)  │ (None, 8, 8, 160) │          0 │ block_13_project… │
# │                     │                   │            │ block_14_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand     │ (None, 8, 8, 960) │    153,600 │ block_14_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_BN  │ (None, 8, 8, 960) │      3,840 │ block_15_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_expand_re… │ (None, 8, 8, 960) │          0 │ block_15_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise  │ (None, 8, 8, 960) │      8,640 │ block_15_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 8, 8, 960) │      3,840 │ block_15_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_depthwise… │ (None, 8, 8, 960) │          0 │ block_15_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project    │ (None, 8, 8, 160) │    153,600 │ block_15_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_project_BN │ (None, 8, 8, 160) │        640 │ block_15_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_15_add (Add)  │ (None, 8, 8, 160) │          0 │ block_14_add[0][… │
# │                     │                   │            │ block_15_project… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand     │ (None, 8, 8, 960) │    153,600 │ block_15_add[0][… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_BN  │ (None, 8, 8, 960) │      3,840 │ block_16_expand[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_expand_re… │ (None, 8, 8, 960) │          0 │ block_16_expand_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise  │ (None, 8, 8, 960) │      8,640 │ block_16_expand_… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 8, 8, 960) │      3,840 │ block_16_depthwi… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_depthwise… │ (None, 8, 8, 960) │          0 │ block_16_depthwi… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project    │ (None, 8, 8, 320) │    307,200 │ block_16_depthwi… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block_16_project_BN │ (None, 8, 8, 320) │      1,280 │ block_16_project… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1 (Conv2D)     │ (None, 8, 8,      │    409,600 │ block_16_project… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv_1_bn           │ (None, 8, 8,      │      5,120 │ Conv_1[0][0]      │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_relu (ReLU)     │ (None, 8, 8,      │          0 │ Conv_1_bn[0][0]   │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ out_relu[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1024)      │  1,311,744 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1024)      │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    524,800 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │      2,052 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,096,580 (15.63 MB)
#  Trainable params: 1,838,596 (7.01 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# Train the model
early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
h = model.fit(x=X_train_norm, y=Y_train, epochs=20, validation_split=0.2, batch_size=16, callbacks=[early_stop])
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 227, 227, 3))
#   warnings.warn(msg)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 585ms/step - accuracy: 0.5756 - loss: 2.7712 - val_accuracy: 0.9764 - val_loss: 1.3733
# Epoch 2/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.9636 - loss: 1.3895 - val_accuracy: 0.9921 - val_loss: 1.1676
# Epoch 3/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9888 - loss: 1.1463 - val_accuracy: 1.0000 - val_loss: 1.0297
# Epoch 4/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9786 - loss: 1.0538 - val_accuracy: 0.9528 - val_loss: 1.0264
# Epoch 5/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9695 - loss: 1.0323 - val_accuracy: 1.0000 - val_loss: 0.8609
# Epoch 6/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 0.8440 - val_accuracy: 1.0000 - val_loss: 0.7860
# Epoch 7/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9988 - loss: 0.7731 - val_accuracy: 1.0000 - val_loss: 0.7224
# Epoch 8/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9991 - loss: 0.7110 - val_accuracy: 1.0000 - val_loss: 0.6659
# Epoch 9/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 0.6568 - val_accuracy: 1.0000 - val_loss: 0.6153
# Epoch 10/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9980 - loss: 0.6109 - val_accuracy: 1.0000 - val_loss: 0.5792
# Epoch 11/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9901 - loss: 0.5848 - val_accuracy: 1.0000 - val_loss: 0.5504
# Epoch 12/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9942 - loss: 0.5455 - val_accuracy: 1.0000 - val_loss: 0.5051
# Epoch 13/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9992 - loss: 0.5041 - val_accuracy: 0.9843 - val_loss: 0.5071
# Epoch 14/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9968 - loss: 0.4778 - val_accuracy: 1.0000 - val_loss: 0.4467
# Epoch 15/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9966 - loss: 0.4474 - val_accuracy: 1.0000 - val_loss: 0.4193
# Epoch 16/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9995 - loss: 0.4148 - val_accuracy: 1.0000 - val_loss: 0.3929
# Epoch 17/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9929 - loss: 0.4092 - val_accuracy: 1.0000 - val_loss: 0.3797
# Epoch 18/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9793 - loss: 0.4514 - val_accuracy: 1.0000 - val_loss: 0.3755
# Epoch 19/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9756 - loss: 0.4840 - val_accuracy: 0.9921 - val_loss: 0.4005
# Epoch 20/20
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9647 - loss: 0.5957 - val_accuracy: 1.0000 - val_loss: 0.3932

# %%
train_loss = h.history['loss']
val_loss = h.history['val_loss']
train_acc = h.history['accuracy']
val_acc = h.history['val_accuracy']

# %%
epoch = range(1, len(val_acc)+1)
epoch
# Out:
# range(1, 21)

# %%
epoch = range(1, len(val_acc)+1)
plt.figure(figsize=(20,8))
plt.subplot(1,2,1)
plt.plot(epoch, train_loss,'bo-', label='Training Loss')
plt.plot(epoch, val_loss,'ro-', label= 'Validation loss')
plt.ylim(0,10)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epoch, train_acc,'bo-', label='Train Accuracy')
plt.plot(epoch, val_acc,'ro-', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# Evaluate on test set
test_loss, test_acc = model.evaluate(X_test_norm, Y_test)
print('\nTest Accuracy:', test_acc)
print('\nTest Loss:', test_loss)

# Prediction and visualization
probability = model.predict(X_test_norm)

c=0
label=[0,1,2,3]
plt.figure(figsize=(20,10))
for i in range(min(20, len(X_test))):
    plt.subplot(5,8,c+1)
    img = cv2.cvtColor(X_test[i], cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.xlabel(Y_test[i][0])
    if(Y_test[i][0] == probability[i].argmax()):
        plt.ylabel(probability[i].argmax(), color='g')
    else:
        plt.ylabel(probability[i].argmax(), color='r')
    plt.xticks([])
    plt.yticks([])
    plt.subplot(5,8,c+2)
    plt.bar(range(len(probability[i])), probability[i], color='skyblue')
    plt.xticks(range(len(label)), label)
    c+=2
plt.show()

# Save the model
model.save("/content/drive/MyDrive/model_MobileNet5.h5")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9850 - loss: 0.3991
#
# Test Accuracy: 0.9910714030265808
#
# Test Loss: 0.39006879925727844
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
